# %%
from keras.datasets import mnist
from keras.layers import Input, Dense, Dropout
from keras.models import Model
from keras.optimizers import Adam
from keras.losses import mse
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
(xTrain0, _), (xVal0, _) = mnist.load_data()
xTrain0, xVal0 = xTrain0.reshape(60000,784)/255., xVal0.reshape(10000,784)/255.

xTrain, xVal = xTrain0.copy(), xVal0.copy()
for i in range(60000):
    xTrain[i]+=0.3*np.random.randn(784)
for i in range(10000):
    xVal[i]+=0.3*np.random.randn(784)

# %%
inputL = Input(shape=(784,))
x = Dense(512, activation='relu')(inputL)
x = Dropout(0.1)(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.1)(x)
x = Dense(2, activation='relu')(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.1)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.1)(x)
outputL = Dense(784, activation='relu')(x)
model = Model(inputL, outputL)
model.summary()
model.compile(optimizer=Adam(lr=0.0001), loss=mse)
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               401920
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 2)                 130
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                192
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               33280
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 784)               402192
# =================================================================
# Total params: 870,546
# Trainable params: 870,546
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(xTrain, xTrain0, validation_data=(xVal, xVal0), epochs=50, batch_size=10000)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 5s 75us/step - loss: 0.0553 - val_loss: 0.0538
# Epoch 2/50
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0552 - val_loss: 0.0537
# Epoch 3/50
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0552 - val_loss: 0.0537
# Epoch 4/50
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0552 - val_loss: 0.0537
# Epoch 5/50
# 60000/60000 [==============================] - 4s 71us/step - loss: 0.0551 - val_loss: 0.0536
# Epoch 6/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0550 - val_loss: 0.0536
# Epoch 7/50
# 60000/60000 [==============================] - 4s 72us/step - loss: 0.0550 - val_loss: 0.0535
# Epoch 8/50
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0549 - val_loss: 0.0535
# Epoch 9/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0549 - val_loss: 0.0534
# Epoch 10/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0548 - val_loss: 0.0534
# Epoch 11/50
# 60000/60000 [==============================] - 4s 72us/step - loss: 0.0548 - val_loss: 0.0534
# Epoch 12/50
# 60000/60000 [==============================] - 5s 77us/step - loss: 0.0547 - val_loss: 0.0533
# Epoch 13/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.0547 - val_loss: 0.0533
# Epoch 14/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.0546 - val_loss: 0.0532
# Epoch 15/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.0546 - val_loss: 0.0532
# Epoch 16/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.0546 - val_loss: 0.0531
# Epoch 17/50
# 60000/60000 [==============================] - 5s 80us/step - loss: 0.0545 - val_loss: 0.0531
# Epoch 18/50
# 60000/60000 [==============================] - 5s 85us/step - loss: 0.0544 - val_loss: 0.0531
# Epoch 19/50
# 60000/60000 [==============================] - 5s 84us/step - loss: 0.0544 - val_loss: 0.0530
# Epoch 20/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.0544 - val_loss: 0.0530
# Epoch 21/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.0543 - val_loss: 0.0529
# Epoch 22/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.0542 - val_loss: 0.0529
# Epoch 23/50
# 60000/60000 [==============================] - 5s 80us/step - loss: 0.0542 - val_loss: 0.0528
# Epoch 24/50
# 60000/60000 [==============================] - 5s 80us/step - loss: 0.0542 - val_loss: 0.0528
# Epoch 25/50
# 60000/60000 [==============================] - 5s 79us/step - loss: 0.0541 - val_loss: 0.0528
# Epoch 26/50
# 60000/60000 [==============================] - 5s 77us/step - loss: 0.0541 - val_loss: 0.0527
# Epoch 27/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.0540 - val_loss: 0.0527
# Epoch 28/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.0540 - val_loss: 0.0526
# Epoch 29/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.0539 - val_loss: 0.0526
# Epoch 30/50
# 60000/60000 [==============================] - 5s 85us/step - loss: 0.0539 - val_loss: 0.0525
# Epoch 31/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.0538 - val_loss: 0.0525
# Epoch 32/50
# 60000/60000 [==============================] - 5s 81us/step - loss: 0.0538 - val_loss: 0.0525
# Epoch 33/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.0537 - val_loss: 0.0524
# Epoch 34/50
# 60000/60000 [==============================] - 5s 79us/step - loss: 0.0537 - val_loss: 0.0524
# Epoch 35/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.0537 - val_loss: 0.0523
# Epoch 36/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.0536 - val_loss: 0.0523
# Epoch 37/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.0535 - val_loss: 0.0523
# Epoch 38/50
# 60000/60000 [==============================] - 5s 78us/step - loss: 0.0535 - val_loss: 0.0522
# Epoch 39/50
# 60000/60000 [==============================] - 5s 81us/step - loss: 0.0535 - val_loss: 0.0522
# Epoch 40/50
# 60000/60000 [==============================] - 5s 80us/step - loss: 0.0534 - val_loss: 0.0521
# Epoch 41/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.0534 - val_loss: 0.0521
# Epoch 42/50
# 60000/60000 [==============================] - 5s 81us/step - loss: 0.0533 - val_loss: 0.0520
# Epoch 43/50
# 60000/60000 [==============================] - 5s 77us/step - loss: 0.0533 - val_loss: 0.0520
# Epoch 44/50
# 60000/60000 [==============================] - 5s 81us/step - loss: 0.0533 - val_loss: 0.0520
# Epoch 45/50
# 60000/60000 [==============================] - 5s 80us/step - loss: 0.0532 - val_loss: 0.0519
# Epoch 46/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.0532 - val_loss: 0.0519
# Epoch 47/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.0531 - val_loss: 0.0518
# Epoch 48/50
# 60000/60000 [==============================] - 5s 83us/step - loss: 0.0531 - val_loss: 0.0518
# Epoch 49/50
# 60000/60000 [==============================] - 5s 80us/step - loss: 0.0530 - val_loss: 0.0518
# Epoch 50/50
# 60000/60000 [==============================] - 5s 82us/step - loss: 0.0530 - val_loss: 0.0517

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(labels=['loss', 'val_loss'])
plt.show()#150

# %%
pred = model.predict(xTrain)

# %%
plt.figure(figsize=(20,5))
for i in range(10):
    plt.subplot(3,10,i+1)
    plt.imshow(xTrain0[i].reshape(28,28))
    plt.axis('off')
    plt.subplot(3,10,11+i)
    plt.imshow(xTrain[i].reshape(28,28))
    plt.axis('off')
    plt.subplot(3,10,21+i)
    plt.imshow(pred[i].reshape(28,28))
    plt.axis('off')
plt.show()
