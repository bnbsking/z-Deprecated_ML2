# %%
import numpy as np
from keras.layers import Input, Dense, Dropout
from keras.models import Model
from keras.optimizers import Adam
from keras.losses import mse
#from keras.metrics import accuracy
import matplotlib.pyplot as plt
import math

# %%
X, y, n = np.random.random((1000, 2)), np.zeros((1000, 2)), 1000
for i in range(1000):
    y[i][0] = math.sqrt(X[i][0]**2+X[i][1]**2)
    y[i][1] = math.atan(X[i][1]/X[i][0])
print(X.shape, y.shape)
# Out:
# (1000, 2) (1000, 2)

# %%
z = list(zip(X,y))
np.random.shuffle(z)
X, y = zip(*z)
X, y = np.array(X), np.array(y)

xTrain, yTrain = X[:int(0.8*n)], y[:int(0.8*n)]
xVal, yVal = X[int(0.8*n):], y[int(0.8*n):]
print(xTrain.shape, yTrain.shape, xVal.shape, yVal.shape)
# Out:
# (800, 2) (800, 2) (200, 2) (200, 2)

# %%
inputL = Input(shape=(2,))
x = Dense(64, activation='relu')(inputL)
x = Dropout(0.2)(x)
x = Dense(32, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(2)(x)

model = Model(inputL, x)
model.compile(optimizer=Adam(lr=0.0001), loss=mse)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                192
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 66
# ...
# Total params: 2,338
# Trainable params: 2,338
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(xTrain, yTrain, epochs=2000, validation_data=(xVal, yVal))
# Out:
# WARNING:tensorflow:From c:\users\bnbsking\miniconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 800 samples, validate on 200 samples
# Epoch 1/2000
# 800/800 [==============================] - 0s 183us/step - loss: 0.5800 - val_loss: 0.5395
# Epoch 2/2000
# 800/800 [==============================] - 0s 30us/step - loss: 0.5304 - val_loss: 0.4969
# Epoch 3/2000
# 800/800 [==============================] - 0s 34us/step - loss: 0.4859 - val_loss: 0.4528
# Epoch 4/2000
# 800/800 [==============================] - 0s 31us/step - loss: 0.4417 - val_loss: 0.4076
# Epoch 5/2000
# 800/800 [==============================] - 0s 29us/step - loss: 0.3946 - val_loss: 0.3596
# Epoch 6/2000
# 800/800 [==============================] - 0s 29us/step - loss: 0.3491 - val_loss: 0.3127
# Epoch 7/2000
# ...

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(labels=['loss', 'val_loss'])
plt.show()

# %%
tx, ty = 0.9, 0.5
test = np.array([ [tx,ty] ])

print(model.predict(test))
print(math.sqrt(tx**2+ty**2), math.atan(ty/tx) )
# Out:
# [[1.0140477 0.507692 ]]
# 1.0295630140987 0.507098504392337
